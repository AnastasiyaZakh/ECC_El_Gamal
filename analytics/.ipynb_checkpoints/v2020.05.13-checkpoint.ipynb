# %%
import numpy as np
import src

from jupyterthemes import jtplot
jtplot.style(theme='onedork', context='notebook')

# %% [markdown]
# # Перша задача, неадаптивні алгоритми

# %%
sizes = (1_000, 2_000, 5_000, 10_000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов',
         'Маліцький Tam', 'Кеш. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = src.generate_matrix(size)

    print('\tКорпелевич:', end=' ')
    _, iters['Корпелевич'][size], times['Корпелевич'][size] = \
        src.korpelevich(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tTseng:', end=' ')
    _, iters['Tseng'][size], times['Tseng'][size] = \
        src.tseng(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Tseng:', end=' ')
    _, iters['Кеш. Tseng'][size], times['Кеш. Tseng'][size] = \
        src.cached_tseng(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tПопов:', end=' ')
    _, iters['Попов'][size], times['Попов'][size] = \
        src.popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Попов:', end=' ')
    _, iters['Кеш. Попов'][size], times['Кеш. Попов'][size] = \
        src.cached_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tМаліцький Tam:', end=' ')
    _, iters['Маліцький Tam'][size], times['Маліцький Tam'][size] = \
        src.malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Маліцький Tam:', end=' ')
    _, iters['Кеш. Маліцький Tam'][size], times['Кеш. Маліцький Tam'][size] = \
        src.cached_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print()
# Out:
# Розмір задачі = 1000:
# 	Корпелевич: Took 132 iterations and 0.14 seconds to converge.
# 	Tseng: Took 132 iterations and 0.16 seconds to converge.
# 	Кеш. Tseng: Took 132 iterations and 0.12 seconds to converge.
# 	Попов: Took 89 iterations and 0.11 seconds to converge.
# 	Кеш. Попов: Took 89 iterations and 0.06 seconds to converge.
# 	Маліцький Tam: Took 91 iterations and 0.11 seconds to converge.
# 	Кеш. Маліцький Tam: Took 91 iterations and 0.04 seconds to converge.
#
# Розмір задачі = 2000:
# 	Корпелевич: Took 137 iterations and 0.82 seconds to converge.
# 	Tseng: Took 137 iterations and 1.19 seconds to converge.
# 	Кеш. Tseng: Took 137 iterations and 0.81 seconds to converge.
# 	Попов: Took 92 iterations and 0.54 seconds to converge.
# 	Кеш. Попов: Took 92 iterations and 0.28 seconds to converge.
# 	Маліцький Tam: Took 94 iterations and 0.89 seconds to converge.
# 	Кеш. Маліцький Tam: Took 94 iterations and 0.31 seconds to converge.
#
# Розмір задачі = 5000:
# 	Корпелевич: Took 144 iterations and 5.62 seconds to converge.
# 	Tseng: Took 144 iterations and 8.17 seconds to converge.
# 	Кеш. Tseng: Took 144 iterations and 5.34 seconds to converge.
# 	Попов: Took 96 iterations and 3.63 seconds to converge.
# 	Кеш. Попов: Took 96 iterations and 1.84 seconds to converge.
# 	Маліцький Tam: Took 98 iterations and 5.54 seconds to converge.
# 	Кеш. Маліцький Tam: Took 98 iterations and 1.85 seconds to converge.
#
# Розмір задачі = 10000:
# 	Корпелевич: Took 148 iterations and 22.10 seconds to converge.
# 	Tseng: Took 148 iterations and 33.47 seconds to converge.
# 	Кеш. Tseng: Took 148 iterations and 22.18 seconds to converge.
# 	Попов: Took 99 iterations and 15.71 seconds to converge.
# 	Кеш. Попов: Took 99 iterations and 7.80 seconds to converge.
# 	Маліцький Tam: Took 101 iterations and 23.41 seconds to converge.
# 	Кеш. Маліцький Tam: Took 101 iterations and 7.42 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='1/time', tp='time')
src.save_values_to_table(iters, sizes, fn='1/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='1/time',
                         styles=('c-', 'm-', 'm--', 'y-', 'y--', 'w-', 'w--'),
                         title='Час виконання, секунд')

# %% [markdown]
# # Перша задача, адаптивні алгоритми

# %%
sizes = (1_000, 2_000, 5_000, 10_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич', 'Адапт. Tseng',
         'Кеш. адапт. Tseng', 'Адапт. Попов', 'Кеш. адапт. Попов',
         'Адапт. Маліцький Tam', 'Кеш. адапт. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = src.generate_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
        src.adaptive_korpelevich(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
        src.cached_adaptive_korpelevich(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
        src.adaptive_tseng(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
        src.cached_adaptive_tseng(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
        src.adaptive_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. адапт. Попов:', end=' ')
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
        src.cached_adaptive_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tАдапт. Маліцький Tam:', end=' ')
    _, iters['Адапт. Маліцький Tam'][size], times['Адапт. Маліцький Tam'][size] = \
        src.adaptive_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            tau=.4,
            lambda0_initial=1,
            lambda1_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. адапт. Маліцький Tam:', end=' ')
    _, iters['Кеш. адапт. Маліцький Tam'][size], times['Кеш. адапт. Маліцький Tam'][size] = \
        src.cached_adaptive_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            tau=.4,
            lambda0_initial=1,
            lambda1_initial=1,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print()
# Out:
# Розмір задачі = 1000:
# 	Адапт. Корпелевич: Took 133 iterations and 0.40 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 133 iterations and 0.10 seconds to converge.
# 	Адапт. Tseng: Took 133 iterations and 0.32 seconds to converge.
# 	Кеш. адапт. Tseng: Took 133 iterations and 0.10 seconds to converge.
# 	Адапт. Попов: Took 90 iterations and 0.20 seconds to converge.
# 	Кеш. адапт. Попов: Took 90 iterations and 0.05 seconds to converge.
# 	Адапт. Маліцький Tam: Took 92 iterations and 0.22 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 92 iterations and 0.05 seconds to converge.
#
# Розмір задачі = 2000:
# 	Адапт. Корпелевич: Took 138 iterations and 2.26 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 138 iterations and 0.77 seconds to converge.
# 	Адапт. Tseng: Took 138 iterations and 2.63 seconds to converge.
# 	Кеш. адапт. Tseng: Took 138 iterations and 0.81 seconds to converge.
# 	Адапт. Попов: Took 93 iterations and 1.53 seconds to converge.
# 	Кеш. адапт. Попов: Took 93 iterations and 0.29 seconds to converge.
# 	Адапт. Маліцький Tam: Took 95 iterations and 1.84 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 95 iterations and 0.30 seconds to converge.
#
# Розмір задачі = 5000:
# 	Адапт. Корпелевич: Took 145 iterations and 15.87 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 145 iterations and 5.32 seconds to converge.
# 	Адапт. Tseng: Took 145 iterations and 18.43 seconds to converge.
# 	Кеш. адапт. Tseng: Took 145 iterations and 5.40 seconds to converge.
# 	Адапт. Попов: Took 97 iterations and 12.26 seconds to converge.
# 	Кеш. адапт. Попов: Took 97 iterations and 2.05 seconds to converge.
# 	Адапт. Маліцький Tam: Took 99 iterations and 13.77 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 99 iterations and 2.24 seconds to converge.
#
# Розмір задачі = 10000:
# 	Адапт. Корпелевич: Took 149 iterations and 67.82 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 149 iterations and 19.78 seconds to converge.
# 	Адапт. Tseng: Took 149 iterations and 67.32 seconds to converge.
# 	Кеш. адапт. Tseng: Took 149 iterations and 19.48 seconds to converge.
# 	Адапт. Попов: Took 100 iterations and 39.53 seconds to converge.
# 	Кеш. адапт. Попов: Took 100 iterations and 6.54 seconds to converge.
# 	Адапт. Маліцький Tam: Took 102 iterations and 46.15 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 102 iterations and 6.58 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='1/adapt/time', tp='time')
src.save_values_to_table(iters, sizes, fn='1/adapt/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='1/adapt/time',
                         styles=('c-', 'c--', 'm-', 'm--', 'y-', 'y--', 'w-', 'w--'),
                         title='Час виконання, секунд')

# %% [markdown]
# # Перша задача із розрідженими матрицями, неадаптивні алгоритми

# %%
sizes = (50_000, 100_000, 200_000, 500_000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов',
         'Маліцький Tam', 'Кеш. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = src.generate_sparse_matrix(size)

    print('\tКорпелевич:', end=' ')
    _, iters['Корпелевич'][size], times['Корпелевич'][size] = \
        src.korpelevich(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tTseng:', end=' ')
    _, iters['Tseng'][size], times['Tseng'][size] = \
        src.tseng(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Tseng:', end=' ')
    _, iters['Кеш. Tseng'][size], times['Кеш. Tseng'][size] = \
        src.cached_tseng(
            x_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tPopov:', end=' ')
    _, iters['Попов'][size], times['Попов'][size] = \
        src.popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Попов:', end=' ')
    _, iters['Кеш. Попов'][size], times['Кеш. Попов'][size] = \
        src.cached_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tМаліцький Tam:', end=' ')
    _, iters['Маліцький Tam'][size], times['Маліцький Tam'][size] = \
        src.malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print('\tКеш. Маліцький Tam:', end=' ')
    _, iters['Кеш. Маліцький Tam'][size], times['Кеш. Маліцький Tam'][size] = \
        src.cached_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=0.4,
            A=lambda x: a.dot(x),
            ProjectionOntoC=lambda x: x,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)

    print()
# Out:
# Розмір задачі = 50000:
# 	Корпелевич: Took 159 iterations and 0.09 seconds to converge.
# 	Tseng: Took 159 iterations and 0.12 seconds to converge.
# 	Кеш. Tseng: Took 159 iterations and 0.10 seconds to converge.
# 	Popov: Took 106 iterations and 0.06 seconds to converge.
# 	Кеш. Попов: Took 106 iterations and 0.04 seconds to converge.
# 	Маліцький Tam: Took 108 iterations and 0.07 seconds to converge.
# 	Кеш. Маліцький Tam: Took 108 iterations and 0.04 seconds to converge.
#
# Розмір задачі = 100000:
# 	Корпелевич: Took 164 iterations and 0.24 seconds to converge.
# 	Tseng: Took 164 iterations and 0.38 seconds to converge.
# 	Кеш. Tseng: Took 164 iterations and 0.33 seconds to converge.
# 	Popov: Took 109 iterations and 0.21 seconds to converge.
# 	Кеш. Попов: Took 109 iterations and 0.17 seconds to converge.
# 	Маліцький Tam: Took 111 iterations and 0.38 seconds to converge.
# 	Кеш. Маліцький Tam: Took 111 iterations and 0.17 seconds to converge.
#
# Розмір задачі = 200000:
# 	Корпелевич: Took 169 iterations and 1.71 seconds to converge.
# 	Tseng: Took 169 iterations and 2.06 seconds to converge.
# 	Кеш. Tseng: Took 169 iterations and 2.54 seconds to converge.
# 	Popov: Took 112 iterations and 1.01 seconds to converge.
# 	Кеш. Попов: Took 112 iterations and 0.75 seconds to converge.
# 	Маліцький Tam: Took 114 iterations and 1.56 seconds to converge.
# 	Кеш. Маліцький Tam: Took 114 iterations and 1.40 seconds to converge.
#
# Розмір задачі = 500000:
# 	Корпелевич: Took 175 iterations and 4.89 seconds to converge.
# 	Tseng: Took 175 iterations and 6.88 seconds to converge.
# 	Кеш. Tseng: Took 175 iterations and 5.56 seconds to converge.
# 	Popov: Took 117 iterations and 2.85 seconds to converge.
# 	Кеш. Попов: Took 117 iterations and 3.21 seconds to converge.
# 	Маліцький Tam: Took 119 iterations and 4.33 seconds to converge.
# 	Кеш. Маліцький Tam: Took 119 iterations and 2.87 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='1/sparse/time', tp='time')
src.save_values_to_table(iters, sizes, fn='1/sparse/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='1/sparse/time',
                         styles=('c-', 'm-', 'm--', 'y-', 'y--', 'w-', 'w--'),
                         title='Час виконання, секунд')

# %% [markdown]
# # Перша задача із розрідженими матрицями, адаптивні алгоритми

# %%
sizes = (50_000, 100_000, 200_000, 500_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич', 'Адапт. Tseng',
         'Кеш. адапт. Tseng', 'Адапт. Попов', 'Кеш. адапт. Попов',
         'Адапт. Маліцький Tam', 'Кеш. адапт. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = src.generate_sparse_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          src.adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                   A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                   tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          src.cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                          A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                          tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          src.adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                             A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                             tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          src.cached_adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                    A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                    tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          src.adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                             tau=.4, lambda_initial=1,
                             A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                             tolerance=1e-3, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          src.cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                    tau=.4, lambda_initial=1,
                                    A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                    tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Маліцький Tam:', end=' ')
    _, iters['Адапт. Маліцький Tam'][size], times['Адапт. Маліцький Tam'][size] = \
          src.adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                     tau=.4, lambda0_initial=1, lambda1_initial=1,
                                     A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                     tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Маліцький Tam:', end=' ')
    _, iters['Кеш. адапт. Маліцький Tam'][size], times['Кеш. адапт. Маліцький Tam'][size] = \
          src.cached_adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                            tau=.4, lambda0_initial=1, lambda1_initial=1,
                                            A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                            tolerance=1e-3, max_iterations=1e4, debug=True)

    print()
# Out:
# Розмір задачі = 50000:
# 	Адапт. Корпелевич: Took 160 iterations and 0.46 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 160 iterations and 0.47 seconds to converge.
# 	Адапт. Tseng: Took 160 iterations and 0.56 seconds to converge.
# 	Кеш. адапт. Tseng: Took 160 iterations and 0.28 seconds to converge.
# 	Адапт. Попов: Took 108 iterations and 0.34 seconds to converge.
# 	Кеш. адапт. Попов: Took 108 iterations and 0.15 seconds to converge.
# 	Адапт. Маліцький Tam: Took 110 iterations and 0.34 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 110 iterations and 0.18 seconds to converge.
#
# Розмір задачі = 100000:
# 	Адапт. Корпелевич: Took 165 iterations and 1.17 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 165 iterations and 0.65 seconds to converge.
# 	Адапт. Tseng: Took 165 iterations and 0.82 seconds to converge.
# 	Кеш. адапт. Tseng: Took 165 iterations and 0.66 seconds to converge.
# 	Адапт. Попов: Took 111 iterations and 1.01 seconds to converge.
# 	Кеш. адапт. Попов: Took 111 iterations and 0.54 seconds to converge.
# 	Адапт. Маліцький Tam: Took 113 iterations and 0.72 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 113 iterations and 0.35 seconds to converge.
#
# Розмір задачі = 200000:
# 	Адапт. Корпелевич: Took 170 iterations and 4.79 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 170 iterations and 3.07 seconds to converge.
# 	Адапт. Tseng: Took 170 iterations and 5.05 seconds to converge.
# 	Кеш. адапт. Tseng: Took 170 iterations and 2.28 seconds to converge.
# 	Адапт. Попов: Took 114 iterations and 3.81 seconds to converge.
# 	Кеш. адапт. Попов: Took 114 iterations and 1.29 seconds to converge.
# 	Адапт. Маліцький Tam: Took 116 iterations and 4.01 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 116 iterations and 1.63 seconds to converge.
#
# Розмір задачі = 500000:
# 	Адапт. Корпелевич: Took 176 iterations and 14.42 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 176 iterations and 7.71 seconds to converge.
# 	Адапт. Tseng: Took 176 iterations and 14.63 seconds to converge.
# 	Кеш. адапт. Tseng: Took 176 iterations and 8.52 seconds to converge.
# 	Адапт. Попов: Took 118 iterations and 9.89 seconds to converge.
# 	Кеш. адапт. Попов: Took 118 iterations and 4.83 seconds to converge.
# 	Адапт. Маліцький Tam: Took 120 iterations and 9.59 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 120 iterations and 4.89 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='1/sparse/adapt/time', tp='time')
src.save_values_to_table(iters, sizes, fn='1/sparse/adapt/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='1/sparse/adapt/time',
                         styles=('c-', 'c--', 'm-', 'm--', 'y-', 'y--', 'w-',
                                 'w--'),
                         title='Час виконання, секунд')

# %% [markdown]
# # Друга задача, неадаптивні алгоритми

# %%
def ProjectionOntoProbabilitySymplex(x: np.array) -> np.array:
    """ computes projection onto (scaled) a probability symplex """
    dimensionality = x.shape[0]
    x /= dimensionality
    sorted_x = np.flip(np.sort(x))
    prefix_sum = np.cumsum(sorted_x)
    to_compare = sorted_x + (1 - prefix_sum) / np.arange(1, dimensionality + 1)
    k = 0
    for j in range(1, dimensionality):
        if to_compare[j] > 0:
            k = j
    return dimensionality * np.maximum(np.zeros(dimensionality), x +
                                       (to_compare[k] - sorted_x[k]))

# %%
sizes = (100, 200, 500, 1000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов',
         'Маліцький Tam', 'Кеш. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')

    for algo in algos:
        iters[algo][size] = []
        times[algo][size] = []

    for _ in range(5):
        print(f'\tTry #{_ + 1}:')

        np.random.seed(_)
        M, q = src.generate_random_matrix(size)

        print('\t\tКорпелевич:', end=' ')
        _, iter_, time_ = src.korpelevich(
            x_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Корпелевич'][size].append(iter_)
        times['Корпелевич'][size].append(time_)

        print('\t\tTseng:', end=' ')
        _, iter_, time_ = src.tseng(
            x_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Tseng'][size].append(iter_)
        times['Tseng'][size].append(time_)

        print('\t\tКеш. Tseng:', end=' ')
        _, iter_, time_ = src.cached_tseng(
            x_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. Tseng'][size].append(iter_)
        times['Кеш. Tseng'][size].append(time_)

        print('\t\tПопов:', end=' ')
        _, iter_, time_ = src.popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Попов'][size].append(iter_)
        times['Попов'][size].append(time_)

        print('\t\tКеш. Попов:', end=' ')
        _, iter_, time_ = src.cached_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. Попов'][size].append(iter_)
        times['Кеш. Попов'][size].append(time_)

        print('\t\tМаліцький Tam:', end=' ')
        _, iter_, time_ = src.malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Маліцький Tam'][size].append(iter_)
        times['Маліцький Tam'][size].append(time_)

        print('\t\tКеш. Маліцький Tam:', end=' ')
        _, iter_, time_ = src.cached_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            lambda_=.4 / np.linalg.norm(M),
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. Маліцький Tam'][size].append(iter_)
        times['Кеш. Маліцький Tam'][size].append(time_)

        print()

    print()
# Out:
# Розмір задачі = 100:
# 	Try #1:
# 		Корпелевич: Took 967 iterations and 0.61 seconds to converge.
# 		Tseng: Took 967 iterations and 0.46 seconds to converge.
# 		Кеш. Tseng: Took 967 iterations and 0.38 seconds to converge.
# 		Попов: Took 967 iterations and 0.53 seconds to converge.
# 		Кеш. Попов: Took 967 iterations and 0.42 seconds to converge.
# 		Маліцький Tam: Took 967 iterations and 0.46 seconds to converge.
# 		Кеш. Маліцький Tam: Took 967 iterations and 0.13 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 1151 iterations and 0.29 seconds to converge.
# 		Tseng: Took 1151 iterations and 0.25 seconds to converge.
# 		Кеш. Tseng: Took 1151 iterations and 0.21 seconds to converge.
# 		Попов: Took 1151 iterations and 0.32 seconds to converge.
# 		Кеш. Попов: Took 1151 iterations and 0.51 seconds to converge.
# 		Маліцький Tam: Took 1151 iterations and 0.62 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1151 iterations and 0.36 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 1086 iterations and 0.61 seconds to converge.
# 		Tseng: Took 1086 iterations and 0.52 seconds to converge.
# 		Кеш. Tseng: Took 1086 iterations and 0.47 seconds to converge.
# 		Попов: Took 1086 iterations and 0.59 seconds to converge.
# 		Кеш. Попов: Took 1086 iterations and 0.51 seconds to converge.
# 		Маліцький Tam: Took 1086 iterations and 0.55 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1086 iterations and 0.34 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 1456 iterations and 0.89 seconds to converge.
# 		Tseng: Took 1456 iterations and 0.86 seconds to converge.
# 		Кеш. Tseng: Took 1456 iterations and 0.55 seconds to converge.
# 		Попов: Took 1456 iterations and 0.85 seconds to converge.
# 		Кеш. Попов: Took 1456 iterations and 0.67 seconds to converge.
# 		Маліцький Tam: Took 1456 iterations and 0.39 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1456 iterations and 0.19 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 1221 iterations and 0.35 seconds to converge.
# 		Tseng: Took 1221 iterations and 0.35 seconds to converge.
# 		Кеш. Tseng: Took 1221 iterations and 0.49 seconds to converge.
# 		Попов: Took 1221 iterations and 0.64 seconds to converge.
# 		Кеш. Попов: Took 1221 iterations and 0.56 seconds to converge.
# 		Маліцький Tam: Took 1221 iterations and 0.57 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1221 iterations and 0.37 seconds to converge.
#
#
# Розмір задачі = 200:
# 	Try #1:
# 		Корпелевич: Took 1849 iterations and 1.01 seconds to converge.
# 		Tseng: Took 1849 iterations and 0.48 seconds to converge.
# 		Кеш. Tseng: Took 1849 iterations and 0.43 seconds to converge.
# 		Попов: Took 1849 iterations and 1.33 seconds to converge.
# 		Кеш. Попов: Took 1849 iterations and 1.18 seconds to converge.
# 		Маліцький Tam: Took 1849 iterations and 1.07 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1849 iterations and 0.69 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 1672 iterations and 0.66 seconds to converge.
# 		Tseng: Took 1672 iterations and 0.44 seconds to converge.
# 		Кеш. Tseng: Took 1672 iterations and 0.55 seconds to converge.
# 		Попов: Took 1672 iterations and 1.21 seconds to converge.
# 		Кеш. Попов: Took 1672 iterations and 1.05 seconds to converge.
# 		Маліцький Tam: Took 1672 iterations and 0.95 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1672 iterations and 0.64 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 1715 iterations and 0.75 seconds to converge.
# 		Tseng: Took 1715 iterations and 0.45 seconds to converge.
# 		Кеш. Tseng: Took 1715 iterations and 0.46 seconds to converge.
# 		Попов: Took 1715 iterations and 1.23 seconds to converge.
# 		Кеш. Попов: Took 1715 iterations and 1.10 seconds to converge.
# 		Маліцький Tam: Took 1715 iterations and 0.96 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1715 iterations and 0.69 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 1638 iterations and 0.75 seconds to converge.
# 		Tseng: Took 1638 iterations and 0.43 seconds to converge.
# 		Кеш. Tseng: Took 1638 iterations and 0.40 seconds to converge.
# 		Попов: Took 1638 iterations and 1.17 seconds to converge.
# 		Кеш. Попов: Took 1638 iterations and 1.03 seconds to converge.
# 		Маліцький Tam: Took 1638 iterations and 0.92 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1638 iterations and 0.64 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 1843 iterations and 0.99 seconds to converge.
# 		Tseng: Took 1843 iterations and 0.49 seconds to converge.
# 		Кеш. Tseng: Took 1843 iterations and 0.44 seconds to converge.
# 		Попов: Took 1843 iterations and 1.37 seconds to converge.
# 		Кеш. Попов: Took 1843 iterations and 1.18 seconds to converge.
# 		Маліцький Tam: Took 1843 iterations and 1.03 seconds to converge.
# 		Кеш. Маліцький Tam: Took 1843 iterations and 0.74 seconds to converge.
#
#
# Розмір задачі = 500:
# 	Try #1:
# 		Корпелевич: Took 2523 iterations and 2.20 seconds to converge.
# 		Tseng: Took 2523 iterations and 2.16 seconds to converge.
# 		Кеш. Tseng: Took 2523 iterations and 2.02 seconds to converge.
# 		Попов: Took 2523 iterations and 2.03 seconds to converge.
# 		Кеш. Попов: Took 2523 iterations and 3.01 seconds to converge.
# 		Маліцький Tam: Took 2523 iterations and 1.06 seconds to converge.
# 		Кеш. Маліцький Tam: Took 2523 iterations and 1.69 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 2543 iterations and 3.50 seconds to converge.
# 		Tseng: Took 2543 iterations and 1.93 seconds to converge.
# 		Кеш. Tseng: Took 2543 iterations and 0.91 seconds to converge.
# 		Попов: Took 2543 iterations and 3.40 seconds to converge.
# 		Кеш. Попов: Took 2543 iterations and 1.92 seconds to converge.
# 		Маліцький Tam: Took 2543 iterations and 2.30 seconds to converge.
# 		Кеш. Маліцький Tam: Took 2543 iterations and 1.86 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 2725 iterations and 2.63 seconds to converge.
# 		Tseng: Took 2725 iterations and 2.17 seconds to converge.
# 		Кеш. Tseng: Took 2725 iterations and 2.22 seconds to converge.
# 		Попов: Took 2725 iterations and 2.14 seconds to converge.
# 		Кеш. Попов: Took 2725 iterations and 3.01 seconds to converge.
# 		Маліцький Tam: Took 2725 iterations and 1.30 seconds to converge.
# 		Кеш. Маліцький Tam: Took 2725 iterations and 1.92 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 2813 iterations and 2.39 seconds to converge.
# 		Tseng: Took 2813 iterations and 2.52 seconds to converge.
# 		Кеш. Tseng: Took 2813 iterations and 2.00 seconds to converge.
# 		Попов: Took 2813 iterations and 2.61 seconds to converge.
# 		Кеш. Попов: Took 2813 iterations and 3.12 seconds to converge.
# 		Маліцький Tam: Took 2813 iterations and 1.44 seconds to converge.
# 		Кеш. Маліцький Tam: Took 2813 iterations and 2.02 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 2869 iterations and 3.91 seconds to converge.
# 		Tseng: Took 2869 iterations and 1.93 seconds to converge.
# 		Кеш. Tseng: Took 2869 iterations and 1.56 seconds to converge.
# 		Попов: Took 2869 iterations and 3.07 seconds to converge.
# 		Кеш. Попов: Took 2869 iterations and 2.82 seconds to converge.
# 		Маліцький Tam: Took 2869 iterations and 2.63 seconds to converge.
# 		Кеш. Маліцький Tam: Took 2869 iterations and 1.33 seconds to converge.
#
#
# Розмір задачі = 1000:
# 	Try #1:
# 		Корпелевич: Took 3542 iterations and 8.20 seconds to converge.
# 		Tseng: Took 3542 iterations and 6.74 seconds to converge.
# 		Кеш. Tseng: Took 3542 iterations and 5.57 seconds to converge.
# 		Попов: Took 3542 iterations and 8.52 seconds to converge.
# 		Кеш. Попов: Took 3542 iterations and 6.17 seconds to converge.
# 		Маліцький Tam: Took 3543 iterations and 6.31 seconds to converge.
# 		Кеш. Маліцький Tam: Took 3543 iterations and 4.59 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 3570 iterations and 8.24 seconds to converge.
# 		Tseng: Took 3570 iterations and 7.57 seconds to converge.
# 		Кеш. Tseng: Took 3570 iterations and 5.25 seconds to converge.
# 		Попов: Took 3570 iterations and 10.12 seconds to converge.
# 		Кеш. Попов: Took 3570 iterations and 6.98 seconds to converge.
# 		Маліцький Tam: Took 3570 iterations and 8.29 seconds to converge.
# 		Кеш. Маліцький Tam: Took 3570 iterations and 3.83 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 3471 iterations and 11.12 seconds to converge.
# 		Tseng: Took 3471 iterations and 7.89 seconds to converge.
# 		Кеш. Tseng: Took 3471 iterations and 5.90 seconds to converge.
# 		Попов: Took 3471 iterations and 8.50 seconds to converge.
# 		Кеш. Попов: Took 3471 iterations and 7.84 seconds to converge.
# 		Маліцький Tam: Took 3471 iterations and 7.16 seconds to converge.
# 		Кеш. Маліцький Tam: Took 3471 iterations and 3.90 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 3918 iterations and 14.56 seconds to converge.
# 		Tseng: Took 3918 iterations and 9.12 seconds to converge.
# 		Кеш. Tseng: Took 3918 iterations and 6.04 seconds to converge.
# 		Попов: Took 3918 iterations and 9.00 seconds to converge.
# 		Кеш. Попов: Took 3918 iterations and 6.14 seconds to converge.
# 		Маліцький Tam: Took 3918 iterations and 7.59 seconds to converge.
# 		Кеш. Маліцький Tam: Took 3918 iterations and 4.02 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 3907 iterations and 8.46 seconds to converge.
# 		Tseng: Took 3907 iterations and 6.99 seconds to converge.
# 		Кеш. Tseng: Took 3907 iterations and 7.78 seconds to converge.
# 		Попов: Took 3907 iterations and 8.97 seconds to converge.
# 		Кеш. Попов: Took 3907 iterations and 7.07 seconds to converge.
# 		Маліцький Tam: Took 3907 iterations and 6.58 seconds to converge.
# 		Кеш. Маліцький Tam: Took 3907 iterations and 3.32 seconds to converge.

# %%
for algo in algos:
    for size in sizes:
        iters[algo][size] = (int(np.mean(iters[algo][size])),
                             int(np.std(iters[algo][size])))
        times[algo][size] = (np.mean(times[algo][size]),
                             np.std(times[algo][size]))

# %%
src.save_intervals_to_table(times, sizes, fn='2/time', tp='time')
src.save_intervals_to_table(iters, sizes, fn='2/iter', tp='iter')

# %%
src.save_intervals_to_image(times,
                            sizes,
                            fn='2/time',
                            styles=('c-', 'm-', 'm--', 'y-', 'y--', 'w-',
                                    'w--'),
                            title='Час виконання, секунд')

# %% [markdown]
# # Друга задача, адаптивні алгоритми

# %%
sizes = (100, 200, 500, 1000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич', 'Адапт. Tseng',
         'Кеш. адапт. Tseng', 'Адапт. Попов', 'Кеш. адапт. Попов',
         'Адапт. Маліцький Tam', 'Кеш. адапт. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')

    for algo in algos:
        iters[algo][size] = []
        times[algo][size] = []

    for _ in range(5):
        print(f'\tTry #{_ + 1}:')

        np.random.seed(_)
        M, q = src.generate_random_matrix(size)

        print('\t\tАдапт. Корпелевич:', end=' ')
        _, iter_, time_ = src.adaptive_korpelevich(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Адапт. Корпелевич'][size].append(iter_)
        times['Адапт. Корпелевич'][size].append(time_)

        print('\t\tКеш. адапт. Корпелевич:', end=' ')
        _, iter_, time_ = src.cached_adaptive_korpelevich(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. адапт. Корпелевич'][size].append(iter_)
        times['Кеш. адапт. Корпелевич'][size].append(time_)

        print('\t\tАдапт. Tseng:', end=' ')
        _, iter_, time_ = src.adaptive_tseng(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Адапт. Tseng'][size].append(iter_)
        times['Адапт. Tseng'][size].append(time_)

        print('\t\tКеш. адапт. Tseng:', end=' ')
        _, iter_, time_ = src.cached_adaptive_tseng(
            x_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. адапт. Tseng'][size].append(iter_)
        times['Кеш. адапт. Tseng'][size].append(time_)

        print('\t\tАдапт. Попов:', end=' ')
        _, iter_, time_ = src.adaptive_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Адапт. Попов'][size].append(iter_)
        times['Адапт. Попов'][size].append(time_)

        print('\t\tКеш. адапт. Попов:', end=' ')
        _, iter_, time_ = src.cached_adaptive_popov(
            x_initial=np.ones(size),
            y_initial=np.ones(size),
            tau=.4,
            lambda_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. адапт. Попов'][size].append(iter_)
        times['Кеш. адапт. Попов'][size].append(time_)

        print('\t\tАдапт. Маліцький Tam:', end=' ')
        _, iter_, time_ = src.adaptive_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            tau=.4,
            lambda0_initial=1,
            lambda1_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Адапт. Маліцький Tam'][size].append(iter_)
        times['Адапт. Маліцький Tam'][size].append(time_)

        print('\t\tКеш. адапт. Маліцький Tam:', end=' ')
        _, iter_, time_ = src.cached_adaptive_malitskyi_tam(
            x0_initial=np.ones(size),
            x1_initial=np.ones(size),
            tau=.4,
            lambda0_initial=1,
            lambda1_initial=1,
            A=lambda x: M.dot(x) + q,
            ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3,
            max_iterations=1e4,
            debug=True)
        iters['Кеш. адапт. Маліцький Tam'][size].append(iter_)
        times['Кеш. адапт. Маліцький Tam'][size].append(time_)

        print()

    print()
# Out:
# Розмір задачі = 100:
# 	Try #1:
# 		Адапт. Корпелевич: Took 253 iterations and 0.25 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 253 iterations and 0.14 seconds to converge.
# 		Адапт. Tseng: Took 432 iterations and 0.38 seconds to converge.
# 		Кеш. адапт. Tseng: Took 432 iterations and 0.20 seconds to converge.
# 		Адапт. Попов: Took 349 iterations and 0.36 seconds to converge.
# 		Кеш. адапт. Попов: Took 349 iterations and 0.18 seconds to converge.
# 		Адапт. Маліцький Tam: Took 464 iterations and 0.42 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 464 iterations and 0.16 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 305 iterations and 0.31 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 305 iterations and 0.17 seconds to converge.
# 		Адапт. Tseng: Took 530 iterations and 0.46 seconds to converge.
# 		Кеш. адапт. Tseng: Took 530 iterations and 0.23 seconds to converge.
# 		Адапт. Попов: Took 451 iterations and 0.41 seconds to converge.
# 		Кеш. адапт. Попов: Took 451 iterations and 0.23 seconds to converge.
# 		Адапт. Маліцький Tam: Took 571 iterations and 0.32 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 571 iterations and 0.09 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 243 iterations and 0.11 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 243 iterations and 0.07 seconds to converge.
# 		Адапт. Tseng: Took 458 iterations and 0.19 seconds to converge.
# 		Кеш. адапт. Tseng: Took 458 iterations and 0.09 seconds to converge.
# 		Адапт. Попов: Took 302 iterations and 0.13 seconds to converge.
# 		Кеш. адапт. Попов: Took 302 iterations and 0.06 seconds to converge.
# 		Адапт. Маліцький Tam: Took 430 iterations and 0.19 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 430 iterations and 0.11 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 372 iterations and 0.34 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 372 iterations and 0.20 seconds to converge.
# 		Адапт. Tseng: Took 533 iterations and 0.48 seconds to converge.
# 		Кеш. адапт. Tseng: Took 533 iterations and 0.24 seconds to converge.
# 		Адапт. Попов: Took 499 iterations and 0.46 seconds to converge.
# 		Кеш. адапт. Попов: Took 499 iterations and 0.25 seconds to converge.
# 		Адапт. Маліцький Tam: Took 540 iterations and 0.46 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 540 iterations and 0.17 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 415 iterations and 0.40 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 415 iterations and 0.25 seconds to converge.
# 		Адапт. Tseng: Took 568 iterations and 0.29 seconds to converge.
# 		Кеш. адапт. Tseng: Took 568 iterations and 0.12 seconds to converge.
# 		Адапт. Попов: Took 553 iterations and 0.29 seconds to converge.
# 		Кеш. адапт. Попов: Took 553 iterations and 0.13 seconds to converge.
# 		Адапт. Маліцький Tam: Took 698 iterations and 0.30 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 698 iterations and 0.11 seconds to converge.
#
#
# Розмір задачі = 200:
# 	Try #1:
# 		Адапт. Корпелевич: Took 397 iterations and 0.52 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 397 iterations and 0.32 seconds to converge.
# 		Адапт. Tseng: Took 727 iterations and 0.77 seconds to converge.
# 		Кеш. адапт. Tseng: Took 727 iterations and 0.41 seconds to converge.
# 		Адапт. Попов: Took 577 iterations and 0.67 seconds to converge.
# 		Кеш. адапт. Попов: Took 577 iterations and 0.41 seconds to converge.
# 		Адапт. Маліцький Tam: Took 560 iterations and 0.57 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 560 iterations and 0.24 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 395 iterations and 0.45 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 395 iterations and 0.29 seconds to converge.
# 		Адапт. Tseng: Took 660 iterations and 0.67 seconds to converge.
# 		Кеш. адапт. Tseng: Took 660 iterations and 0.35 seconds to converge.
# 		Адапт. Попов: Took 541 iterations and 0.60 seconds to converge.
# 		Кеш. адапт. Попов: Took 541 iterations and 0.37 seconds to converge.
# 		Адапт. Маліцький Tam: Took 617 iterations and 0.38 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 617 iterations and 0.12 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 364 iterations and 0.20 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 364 iterations and 0.13 seconds to converge.
# 		Адапт. Tseng: Took 644 iterations and 0.30 seconds to converge.
# 		Кеш. адапт. Tseng: Took 644 iterations and 0.15 seconds to converge.
# 		Адапт. Попов: Took 540 iterations and 0.60 seconds to converge.
# 		Кеш. адапт. Попов: Took 540 iterations and 0.36 seconds to converge.
# 		Адапт. Маліцький Tam: Took 696 iterations and 0.72 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 696 iterations and 0.32 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 363 iterations and 0.45 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 363 iterations and 0.31 seconds to converge.
# 		Адапт. Tseng: Took 736 iterations and 0.74 seconds to converge.
# 		Кеш. адапт. Tseng: Took 736 iterations and 0.37 seconds to converge.
# 		Адапт. Попов: Took 488 iterations and 0.54 seconds to converge.
# 		Кеш. адапт. Попов: Took 488 iterations and 0.33 seconds to converge.
# 		Адапт. Маліцький Tam: Took 633 iterations and 0.63 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 633 iterations and 0.29 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 279 iterations and 0.16 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 279 iterations and 0.09 seconds to converge.
# 		Адапт. Tseng: Took 656 iterations and 0.31 seconds to converge.
# 		Кеш. адапт. Tseng: Took 656 iterations and 0.16 seconds to converge.
# 		Адапт. Попов: Took 392 iterations and 0.20 seconds to converge.
# 		Кеш. адапт. Попов: Took 392 iterations and 0.11 seconds to converge.
# 		Адапт. Маліцький Tam: Took 489 iterations and 0.35 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 489 iterations and 0.21 seconds to converge.
#
#
# Розмір задачі = 500:
# 	Try #1:
# 		Адапт. Корпелевич: Took 421 iterations and 0.73 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 421 iterations and 0.61 seconds to converge.
# 		Адапт. Tseng: Took 800 iterations and 1.15 seconds to converge.
# 		Кеш. адапт. Tseng: Took 800 iterations and 0.54 seconds to converge.
# 		Адапт. Попов: Took 564 iterations and 0.48 seconds to converge.
# 		Кеш. адапт. Попов: Took 564 iterations and 0.34 seconds to converge.
# 		Адапт. Маліцький Tam: Took 593 iterations and 0.65 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 593 iterations and 0.45 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 411 iterations and 0.75 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 411 iterations and 0.59 seconds to converge.
# 		Адапт. Tseng: Took 944 iterations and 1.29 seconds to converge.
# 		Кеш. адапт. Tseng: Took 944 iterations and 0.82 seconds to converge.
# 		Адапт. Попов: Took 548 iterations and 0.51 seconds to converge.
# 		Кеш. адапт. Попов: Took 548 iterations and 0.31 seconds to converge.
# 		Адапт. Маліцький Tam: Took 666 iterations and 0.43 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 666 iterations and 0.50 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 469 iterations and 0.86 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 469 iterations and 0.68 seconds to converge.
# 		Адапт. Tseng: Took 977 iterations and 1.35 seconds to converge.
# 		Кеш. адапт. Tseng: Took 977 iterations and 0.83 seconds to converge.
# 		Адапт. Попов: Took 635 iterations and 0.65 seconds to converge.
# 		Кеш. адапт. Попов: Took 635 iterations and 0.36 seconds to converge.
# 		Адапт. Маліцький Tam: Took 717 iterations and 0.53 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 717 iterations and 0.55 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 371 iterations and 0.63 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 371 iterations and 0.52 seconds to converge.
# 		Адапт. Tseng: Took 827 iterations and 1.14 seconds to converge.
# 		Кеш. адапт. Tseng: Took 827 iterations and 0.49 seconds to converge.
# 		Адапт. Попов: Took 502 iterations and 0.40 seconds to converge.
# 		Кеш. адапт. Попов: Took 502 iterations and 0.31 seconds to converge.
# 		Адапт. Маліцький Tam: Took 572 iterations and 0.48 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 572 iterations and 0.45 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 379 iterations and 0.68 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 379 iterations and 0.55 seconds to converge.
# 		Адапт. Tseng: Took 813 iterations and 1.12 seconds to converge.
# 		Кеш. адапт. Tseng: Took 813 iterations and 0.69 seconds to converge.
# 		Адапт. Попов: Took 507 iterations and 0.94 seconds to converge.
# 		Кеш. адапт. Попов: Took 507 iterations and 0.65 seconds to converge.
# 		Адапт. Маліцький Tam: Took 621 iterations and 0.57 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 621 iterations and 0.20 seconds to converge.
#
#
# Розмір задачі = 1000:
# 	Try #1:
# 		Адапт. Корпелевич: Took 476 iterations and 1.25 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 476 iterations and 1.04 seconds to converge.
# 		Адапт. Tseng: Took 1048 iterations and 3.44 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1048 iterations and 1.96 seconds to converge.
# 		Адапт. Попов: Took 612 iterations and 2.51 seconds to converge.
# 		Кеш. адапт. Попов: Took 612 iterations and 0.98 seconds to converge.
# 		Адапт. Маліцький Tam: Took 672 iterations and 1.83 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 672 iterations and 0.64 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 454 iterations and 1.63 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 454 iterations and 1.23 seconds to converge.
# 		Адапт. Tseng: Took 1008 iterations and 3.42 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1008 iterations and 1.50 seconds to converge.
# 		Адапт. Попов: Took 599 iterations and 1.69 seconds to converge.
# 		Кеш. адапт. Попов: Took 599 iterations and 0.72 seconds to converge.
# 		Адапт. Маліцький Tam: Took 667 iterations and 2.02 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 667 iterations and 0.91 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 398 iterations and 1.65 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 398 iterations and 1.09 seconds to converge.
# 		Адапт. Tseng: Took 918 iterations and 3.35 seconds to converge.
# 		Кеш. адапт. Tseng: Took 918 iterations and 1.81 seconds to converge.
# 		Адапт. Попов: Took 542 iterations and 2.46 seconds to converge.
# 		Кеш. адапт. Попов: Took 542 iterations and 1.25 seconds to converge.
# 		Адапт. Маліцький Tam: Took 613 iterations and 1.59 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 613 iterations and 0.49 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 406 iterations and 1.56 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 406 iterations and 1.08 seconds to converge.
# 		Адапт. Tseng: Took 915 iterations and 2.41 seconds to converge.
# 		Кеш. адапт. Tseng: Took 915 iterations and 1.03 seconds to converge.
# 		Адапт. Попов: Took 567 iterations and 1.81 seconds to converge.
# 		Кеш. адапт. Попов: Took 567 iterations and 1.19 seconds to converge.
# 		Адапт. Маліцький Tam: Took 585 iterations and 1.90 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 585 iterations and 0.80 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 523 iterations and 1.66 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 523 iterations and 0.82 seconds to converge.
# 		Адапт. Tseng: Took 1084 iterations and 3.12 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1084 iterations and 1.90 seconds to converge.
# 		Адапт. Попов: Took 710 iterations and 2.65 seconds to converge.
# 		Кеш. адапт. Попов: Took 710 iterations and 0.87 seconds to converge.
# 		Адапт. Маліцький Tam: Took 700 iterations and 1.93 seconds to converge.
# 		Кеш. адапт. Маліцький Tam: Took 700 iterations and 0.98 seconds to converge.

# %%
for algo in algos:
    for size in sizes:
        iters[algo][size] = (int(np.mean(iters[algo][size])),
                             int(np.std(iters[algo][size])))
        times[algo][size] = (np.mean(times[algo][size]),
                             np.std(times[algo][size]))

# %%
src.save_intervals_to_table(times, sizes, fn='2/adapt/time', tp='time')
src.save_intervals_to_table(iters, sizes, fn='2/adapt/iter', tp='iter')

# %%
src.save_intervals_to_image(times,
                            sizes,
                            fn='2/adapt/time',
                            styles=('c-', 'c--', 'm-', 'm--', 'y-', 'y--',
                                    'w-', 'w--'),
                            title='Час виконання, секунд')

# %% [markdown]
# # Третя задача

# %%
def f(x: np.array) -> np.array:
    """ function for third problem """
    return np.array([
        3 * x[0]**2 + 2 * x[0] * x[1] + 2 * x[1]**2 + x[2] + 3 * x[3] - 6,
        2 * x[0]**2 + x[0] + x[1]**2 + 10 * x[2] + 2 * x[3] - 2,
        3 * x[0]**2 + x[0] * x[1] + 2 * x[1]**2 + 2 * x[2] + 9 * x[3] - 9,
        x[0]**2 + 3 * x[2]**2 + 2 * x[2] + 3 * x[3] - 3
    ])

# %% [markdown]
# # Четверта задача, адаптивні алгоритми

# %%
sizes = (500, 1_000, 2_000, 5_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич', 'Адапт. Tseng',
         'Кеш. адапт. Tseng', 'Адапт. Попов', 'Кеш. адапт. Попов',
         'Адапт. Маліцький Tam', 'Кеш. адапт. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
def f(x: np.array) -> np.array:
    """ function for fourth problem """
    y = np.hstack([[0], x, [0]])
    f1 = y[1:-1]**2 + y[:-2]**2 + y[1:-1] * y[:-2] + y[1:-1] * y[2:]
    return f1 + d.dot(x) + c

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    d, c = src.generate_tridiagonal_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          src.adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                   A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                   tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          src.cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                          A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                          tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          src.adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                             A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                             tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          src.cached_adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                    A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                    tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          src.adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                             tau=.4, lambda_initial=1,
                             A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                             tolerance=1e-6, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          src.cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                    tau=.4, lambda_initial=1,
                                    A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                    tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Маліцький Tam:', end=' ')
    _, iters['Адапт. Маліцький Tam'][size], times['Адапт. Маліцький Tam'][size] = \
          src.adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                     tau=.4, lambda0_initial=1, lambda1_initial=1,
                                     A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                     tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Маліцький Tam:', end=' ')
    _, iters['Кеш. адапт. Маліцький Tam'][size], times['Кеш. адапт. Маліцький Tam'][size] = \
          src.cached_adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                            tau=.4, lambda0_initial=1, lambda1_initial=1,
                                            A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                            tolerance=1e-6, max_iterations=1e4, debug=True)

    print()
# Out:
# Розмір задачі = 500:
# 	Адапт. Корпелевич: Took 111 iterations and 0.16 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 111 iterations and 0.05 seconds to converge.
# 	Адапт. Tseng: Took 558 iterations and 0.73 seconds to converge.
# 	Кеш. адапт. Tseng: Took 558 iterations and 0.27 seconds to converge.
# 	Адапт. Попов: Took 87 iterations and 0.10 seconds to converge.
# 	Кеш. адапт. Попов: Took 87 iterations and 0.03 seconds to converge.
# 	Адапт. Маліцький Tam: Took 232 iterations and 0.30 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 232 iterations and 0.06 seconds to converge.
#
# Розмір задачі = 1000:
# 	Адапт. Корпелевич: Took 113 iterations and 0.28 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 113 iterations and 0.13 seconds to converge.
# 	Адапт. Tseng: Took 572 iterations and 1.33 seconds to converge.
# 	Кеш. адапт. Tseng: Took 572 iterations and 0.37 seconds to converge.
# 	Адапт. Попов: Took 89 iterations and 0.16 seconds to converge.
# 	Кеш. адапт. Попов: Took 89 iterations and 0.04 seconds to converge.
# 	Адапт. Маліцький Tam: Took 238 iterations and 0.53 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 238 iterations and 0.09 seconds to converge.
#
# Розмір задачі = 2000:
# 	Адапт. Корпелевич: Took 116 iterations and 1.61 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 116 iterations and 0.54 seconds to converge.
# 	Адапт. Tseng: Took 587 iterations and 9.58 seconds to converge.
# 	Кеш. адапт. Tseng: Took 587 iterations and 2.78 seconds to converge.
# 	Адапт. Попов: Took 91 iterations and 1.27 seconds to converge.
# 	Кеш. адапт. Попов: Took 91 iterations and 0.22 seconds to converge.
# 	Адапт. Маліцький Tam: Took 243 iterations and 3.95 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 243 iterations and 0.60 seconds to converge.
#
# Розмір задачі = 5000:
# 	Адапт. Корпелевич: Took 119 iterations and 11.57 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 119 iterations and 3.88 seconds to converge.
# 	Адапт. Tseng: Took 605 iterations and 68.73 seconds to converge.
# 	Кеш. адапт. Tseng: Took 605 iterations and 19.73 seconds to converge.
# 	Адапт. Попов: Took 94 iterations and 9.11 seconds to converge.
# 	Кеш. адапт. Попов: Took 94 iterations and 1.57 seconds to converge.
# 	Адапт. Маліцький Tam: Took 251 iterations and 28.52 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 251 iterations and 4.14 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='4/adapt/time', tp='iter')
src.save_values_to_table(iters, sizes, fn='4/adapt/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='4/adapt/time',
                         styles=('c-', 'c--', 'm-', 'm--', 'y-', 'y--', 'w-',
                                 'w--'),
                         title='Час виконання, секунд')

# %% [markdown]
# # Четверта задача із розрідженими матрицями, адаптивні алгоритми

# %%
sizes = (20_000, 50_000, 100_000, 200_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич', 'Адапт. Tseng',
         'Кеш. адапт. Tseng', 'Адапт. Попов', 'Кеш. адапт. Попов',
         'Адапт. Маліцький Tam', 'Кеш. адапт. Маліцький Tam')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    d, c = src.generate_sparse_tridiagonal_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          src.adaptive_korpelevich(x_initial=np.zeros(size), tau=.4, lambda_initial=1,
                                   A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                   tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          src.cached_adaptive_korpelevich(x_initial=np.zeros(size), tau=.4, lambda_initial=1,
                                          A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                          tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          src.adaptive_tseng(x_initial=np.zeros(size), tau=.4, lambda_initial=1,
                             A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                             tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          src.cached_adaptive_tseng(x_initial=np.zeros(size), tau=.4, lambda_initial=1,
                                    A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                    tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          src.adaptive_popov(x_initial=np.zeros(size), y_initial=np.zeros(size),
                             tau=.4, lambda_initial=1,
                             A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                             tolerance=1e-6, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          src.cached_adaptive_popov(x_initial=np.zeros(size), y_initial=np.zeros(size),
                                    tau=.4, lambda_initial=1,
                                    A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                    tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Маліцький Tam:', end=' ')
    _, iters['Адапт. Маліцький Tam'][size], times['Адапт. Маліцький Tam'][size] = \
          src.adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                     tau=.4, lambda0_initial=1, lambda1_initial=1,
                                     A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                     tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Маліцький Tam:', end=' ')
    _, iters['Кеш. адапт. Маліцький Tam'][size], times['Кеш. адапт. Маліцький Tam'][size] = \
          src.cached_adaptive_malitskyi_tam(x0_initial=np.ones(size), x1_initial=np.ones(size),
                                            tau=.4, lambda0_initial=1, lambda1_initial=1,
                                            A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                            tolerance=1e-6, max_iterations=1e4, debug=True)

    print()
# Out:
# Розмір задачі = 20000:
# 	Адапт. Корпелевич: Took 74 iterations and 0.16 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 74 iterations and 0.06 seconds to converge.
# 	Адапт. Tseng: Took 388 iterations and 1.09 seconds to converge.
# 	Кеш. адапт. Tseng: Took 388 iterations and 0.74 seconds to converge.
# 	Адапт. Попов: Took 71 iterations and 0.31 seconds to converge.
# 	Кеш. адапт. Попов: Took 71 iterations and 0.10 seconds to converge.
# 	Адапт. Маліцький Tam: Took 262 iterations and 1.27 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 262 iterations and 0.37 seconds to converge.
#
# Розмір задачі = 50000:
# 	Адапт. Корпелевич: Took 76 iterations and 0.68 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 76 iterations and 0.24 seconds to converge.
# 	Адапт. Tseng: Took 399 iterations and 4.15 seconds to converge.
# 	Кеш. адапт. Tseng: Took 399 iterations and 2.07 seconds to converge.
# 	Адапт. Попов: Took 73 iterations and 0.57 seconds to converge.
# 	Кеш. адапт. Попов: Took 73 iterations and 0.12 seconds to converge.
# 	Адапт. Маліцький Tam: Took 269 iterations and 3.83 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 269 iterations and 0.98 seconds to converge.
#
# Розмір задачі = 100000:
# 	Адапт. Корпелевич: Took 77 iterations and 1.49 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 77 iterations and 0.80 seconds to converge.
# 	Адапт. Tseng: Took 408 iterations and 16.33 seconds to converge.
# 	Кеш. адапт. Tseng: Took 408 iterations and 5.03 seconds to converge.
# 	Адапт. Попов: Took 74 iterations and 1.95 seconds to converge.
# 	Кеш. адапт. Попов: Took 74 iterations and 0.73 seconds to converge.
# 	Адапт. Маліцький Tam: Took 275 iterations and 9.77 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 275 iterations and 2.29 seconds to converge.
#
# Розмір задачі = 200000:
# 	Адапт. Корпелевич: Took 79 iterations and 8.65 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 79 iterations and 5.20 seconds to converge.
# 	Адапт. Tseng: Took 416 iterations and 65.41 seconds to converge.
# 	Кеш. адапт. Tseng: Took 416 iterations and 23.96 seconds to converge.
# 	Адапт. Попов: Took 76 iterations and 9.23 seconds to converge.
# 	Кеш. адапт. Попов: Took 76 iterations and 2.60 seconds to converge.
# 	Адапт. Маліцький Tam: Took 280 iterations and 40.35 seconds to converge.
# 	Кеш. адапт. Маліцький Tam: Took 280 iterations and 11.55 seconds to converge.

# %%
src.save_values_to_table(times, sizes, fn='4/sparse/adapt/time', tp='time')
src.save_values_to_table(iters, sizes, fn='4/sparse/adapt/iter', tp='iter')

# %%
src.save_values_to_image(times,
                         sizes,
                         fn='4/sparse/adapt/time',
                         styles=('c-', 'c--', 'm-', 'm--', 'y-', 'y--', 'w-',
                                 'w--'),
                         title='Час виконання, секунд')
